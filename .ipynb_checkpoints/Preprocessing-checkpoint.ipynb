# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#https://github.com/youonf/recommendation_system/blob/master/content_based_filtering/content_based_recommender_approach1.ipynb
#https://towardsdatascience.com/how-to-build-from-scratch-a-content-based-movie-recommender-with-natural-language-processing-25ad400eb243

# %%
songs_df = pd.read_csv('Data/songs_w_genres_df.csv', index_col='id')
songs_df.head()
# Out:
#                                                                      name  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI                           keep a song in your soul
# 0hbkKFIJm7Z05H8Zl9w30f                               i put a spell on you
# 11m7laMUgmOKqI3oYzuhne                                       golfing papa
# 19Lc5SfJJ5O1oaxY0fpwfh  true house music - xavier santos & carlos gomi...
# 2hJjbsLCytGsnAHfdsLejp                                          xuniverxe
#
#                                       artists  year  explicit  popularity  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI            Mamie Smith  1920         0          12
# 0hbkKFIJm7Z05H8Zl9w30f  Screamin' Jay Hawkins  1920         0           7
# 11m7laMUgmOKqI3oYzuhne            Mamie Smith  1920         0           4
# 19Lc5SfJJ5O1oaxY0fpwfh        Oscar Velazquez  1920         0          17
# 2hJjbsLCytGsnAHfdsLejp                   Mixe  1920         1           2
#
#                         duration_ms  acousticness  danceability  energy  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI       168333      0.991000         0.598   0.224
# 0hbkKFIJm7Z05H8Zl9w30f       150200      0.643000         0.852   0.517
# 11m7laMUgmOKqI3oYzuhne       163827      0.993000         0.647   0.186
# 19Lc5SfJJ5O1oaxY0fpwfh       422087      0.000173         0.730   0.798
# 2hJjbsLCytGsnAHfdsLejp       165224      0.295000         0.704   0.707
#
#                         instrumentalness  liveness  loudness  mode key  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI          0.000522    0.3790   -12.628     0   F
# 0hbkKFIJm7Z05H8Zl9w30f          0.026400    0.0809    -7.261     0   F
# 11m7laMUgmOKqI3oYzuhne          0.000018    0.5190   -12.098     1   C
# 19Lc5SfJJ5O1oaxY0fpwfh          0.801000    0.1280    -7.311     1   D
# 2hJjbsLCytGsnAHfdsLejp          0.000246    0.4020    -6.036     0  A#
#
#                         speechiness    tempo  valence  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI       0.0936  149.976   0.6340
# 0hbkKFIJm7Z05H8Zl9w30f       0.0534   86.889   0.9500
# 11m7laMUgmOKqI3oYzuhne       0.1740   97.600   0.6890
# 19Lc5SfJJ5O1oaxY0fpwfh       0.0425  127.997   0.0422
# 2hJjbsLCytGsnAHfdsLejp       0.0768  122.076   0.2990
#
#                                                              genres
# id
# 0cS0A1fUEUd1EW3FcF8AEI  ['harlem renaissance', 'traditional blues']
# 0hbkKFIJm7Z05H8Zl9w30f               ['blues', 'traditional blues']
# 11m7laMUgmOKqI3oYzuhne  ['harlem renaissance', 'traditional blues']
# 19Lc5SfJJ5O1oaxY0fpwfh                                  ['circuit']
# 2hJjbsLCytGsnAHfdsLejp                               ['glitchcore']

# %%
songs_df.shape
# Out:
# (159101, 18)

# %%
songs_df = songs_df.astype({'acousticness': 'float32', 'danceability': 'float32', 'energy': 'float32', 
                            'instrumentalness': 'float32', 'liveness': 'float32', 'loudness': 'float32', 
                            'speechiness': 'float32', 'tempo': 'float32', 'valence': 'float32',})

# %%
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159101 entries, 0cS0A1fUEUd1EW3FcF8AEI to 3N3Wi5Un7iT8amLezSRwub
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              159101 non-null  object
#  1   artists           159101 non-null  object
#  2   year              159101 non-null  int64
#  3   explicit          159101 non-null  int64
#  4   popularity        159101 non-null  int64
#  5   duration_ms       159101 non-null  int64
#  6   acousticness      159101 non-null  float32
#  7   danceability      159101 non-null  float32
#  8   energy            159101 non-null  float32
#  9   instrumentalness  159101 non-null  float32
#  10  liveness          159101 non-null  float32
#  11  loudness          159101 non-null  float32
#  12  mode              159101 non-null  int64
#  13  key               159101 non-null  object
#  14  speechiness       159101 non-null  float32
#  15  tempo             159101 non-null  float32
#  16  valence           159101 non-null  float32
#  17  genres            125229 non-null  object
# dtypes: float32(9), int64(5), object(4)
# memory usage: 17.6+ MB

# %%
songs_df.index
# Out:
# Index(['0cS0A1fUEUd1EW3FcF8AEI', '0hbkKFIJm7Z05H8Zl9w30f',
#        '11m7laMUgmOKqI3oYzuhne', '19Lc5SfJJ5O1oaxY0fpwfh',
#        '2hJjbsLCytGsnAHfdsLejp', '3HnrHGLE9u2MjHtdobfWl9',
#        '5DlCyqLyX2AOVDTjjkDZ8x', '02FzJbHtqElixxCmrpSCUa',
#        '02i59gYdjlhBmbbWhf8YuK', '06NUxS2XL3efRh0bloxkHm',
#        ...
#        '3NUmUIyzNLBp8bCFMH8Mif', '0fJ1caLzidzTlIL3pPX1eU',
#        '0VCOLfLPC9oOrc90WGp2r3', '660rulYF3eLCuW6rQpiMdL',
#        '0qQPTWtCFnAI4SucF4ytVb', '0sZ6HFSulsrOl6VTBwp6jd',
#        '2LeqqwzobL5ktfQhWA3bHh', '3Glmyv3hbGGTgeR3FZrxJA',
#        '6QGVWUbmlePAiY5zJjfCmT', '3N3Wi5Un7iT8amLezSRwub'],
#       dtype='object', name='id', length=159101)

# %%
songs_df.shape
# Out:
# (159101, 18)

# %%
songs_df.genres = songs_df.genres.str[1:-1]
songs_df.head()
# Out:
#                                                                      name  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI                           keep a song in your soul
# 0hbkKFIJm7Z05H8Zl9w30f                               i put a spell on you
# 11m7laMUgmOKqI3oYzuhne                                       golfing papa
# 19Lc5SfJJ5O1oaxY0fpwfh  true house music - xavier santos & carlos gomi...
# 2hJjbsLCytGsnAHfdsLejp                                          xuniverxe
#
#                                       artists  year  explicit  popularity  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI            Mamie Smith  1920         0          12
# 0hbkKFIJm7Z05H8Zl9w30f  Screamin' Jay Hawkins  1920         0           7
# 11m7laMUgmOKqI3oYzuhne            Mamie Smith  1920         0           4
# 19Lc5SfJJ5O1oaxY0fpwfh        Oscar Velazquez  1920         0          17
# 2hJjbsLCytGsnAHfdsLejp                   Mixe  1920         1           2
#
#                         duration_ms  acousticness  danceability  energy  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI       168333      0.991000         0.598   0.224
# 0hbkKFIJm7Z05H8Zl9w30f       150200      0.643000         0.852   0.517
# 11m7laMUgmOKqI3oYzuhne       163827      0.993000         0.647   0.186
# 19Lc5SfJJ5O1oaxY0fpwfh       422087      0.000173         0.730   0.798
# 2hJjbsLCytGsnAHfdsLejp       165224      0.295000         0.704   0.707
#
#                         instrumentalness  liveness  loudness  mode key  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI          0.000522    0.3790   -12.628     0   F
# 0hbkKFIJm7Z05H8Zl9w30f          0.026400    0.0809    -7.261     0   F
# 11m7laMUgmOKqI3oYzuhne          0.000018    0.5190   -12.098     1   C
# 19Lc5SfJJ5O1oaxY0fpwfh          0.801000    0.1280    -7.311     1   D
# 2hJjbsLCytGsnAHfdsLejp          0.000246    0.4020    -6.036     0  A#
#
#                         speechiness       tempo  valence  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI       0.0936  149.975998   0.6340
# 0hbkKFIJm7Z05H8Zl9w30f       0.0534   86.889000   0.9500
# 11m7laMUgmOKqI3oYzuhne       0.1740   97.599998   0.6890
# 19Lc5SfJJ5O1oaxY0fpwfh       0.0425  127.997002   0.0422
# 2hJjbsLCytGsnAHfdsLejp       0.0768  122.075996   0.2990
#
#                                                            genres
# id
# 0cS0A1fUEUd1EW3FcF8AEI  'harlem renaissance', 'traditional blues'
# 0hbkKFIJm7Z05H8Zl9w30f               'blues', 'traditional blues'
# 11m7laMUgmOKqI3oYzuhne  'harlem renaissance', 'traditional blues'
# 19Lc5SfJJ5O1oaxY0fpwfh                                  'circuit'
# 2hJjbsLCytGsnAHfdsLejp                               'glitchcore'

# %%
songs_df.head()['genres'].str.get_dummies(sep = ",")
# Out:
#                          'traditional blues'  'blues'  'circuit'  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI                     1        0          0
# 0hbkKFIJm7Z05H8Zl9w30f                     1        1          0
# 11m7laMUgmOKqI3oYzuhne                     1        0          0
# 19Lc5SfJJ5O1oaxY0fpwfh                     0        0          1
# 2hJjbsLCytGsnAHfdsLejp                     0        0          0
#
#                         'glitchcore'  'harlem renaissance'
# id
# 0cS0A1fUEUd1EW3FcF8AEI             0                     1
# 0hbkKFIJm7Z05H8Zl9w30f             0                     0
# 11m7laMUgmOKqI3oYzuhne             0                     1
# 19Lc5SfJJ5O1oaxY0fpwfh             0                     0
# 2hJjbsLCytGsnAHfdsLejp             1                     0

# %%
songs_1980s_up = songs_df[songs_df['year'] > 1980]
songs_1980s_up.year.unique()
# Out:
# array([2008, 2018, 2020, 1997, 1991, 2006, 2012, 2011, 2007, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1992, 1993, 1994,
#        1995, 1996, 1998, 1999, 2000, 2019, 2013, 2001, 2016, 2010, 2002,
#        2004, 2005, 2015, 2003, 2009, 2021, 2014, 2017], dtype=int64)

# %%
songs_1980s_down = songs_df[songs_df['year'] < 1980]
songs_1980s_down.year.unique()
# Out:
# array([1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930,
#        1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941,
#        1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952,
#        1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963,
#        1964, 1965, 1966, 1968, 1967, 1969, 1970, 1971, 1972, 1973, 1974,
#        1975, 1976, 1977, 1978, 1979], dtype=int64)

# %%
songs_1980s_down.reset_index(inplace=True)
songs_1980s_down.set_index(['id','name'], inplace=True)

# %%
numerical_songs = songs_1980s_down.select_dtypes(include=['float32'])
numerical_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 84966 entries, ('0cS0A1fUEUd1EW3FcF8AEI', 'keep a song in your soul') to ('2ChZ9Qm0BoT6A4QWIhg7c1', 'paying on time')
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   acousticness      84966 non-null  float32
#  1   danceability      84966 non-null  float32
#  2   energy            84966 non-null  float32
#  3   instrumentalness  84966 non-null  float32
#  4   liveness          84966 non-null  float32
#  5   loudness          84966 non-null  float32
#  6   speechiness       84966 non-null  float32
#  7   tempo             84966 non-null  float32
#  8   valence           84966 non-null  float32
# dtypes: float32(9)
# memory usage: 8.8+ MB

# %%
'''songs_df1 = songs_df
d_list = []

for index, row in songs_df.iterrows():
    for value in str(row['genres']).split(','):
        d_list.append({'name': row['name'], 'value':value})
songs_df1 = songs_df1.append(d_list, ignore_index=True)
songs_df1 = songs_df1.groupby('name')['value'].value_counts()
songs_df1 = songs_df1.unstack(level=-1).fillna(0)'''
# Out:
# "songs_df1 = songs_df\nd_list = []\n\nfor index, row in songs_df.iterrows():\n    for value in str(row['genres']).split(','):\n        d_list.append({'name': row['name'], 'value':value})\nsongs_df1 = songs_df1.append(d_list, ignore_index=True)\nsongs_df1 = songs_df1.groupby('name')['value'].value_counts()\nsongs_df1 = songs_df1.unstack(level=-1).fillna(0)"

# %%
#songs_df1[songs_df1.index == 'i write sins not tragedies']

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(numerical_songs), columns=numerical_songs.columns, index=numerical_songs.index)
df_scaled.head()
# Out:
#                                                                            acousticness  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                0.994980
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                    0.645582
# 11m7laMUgmOKqI3oYzuhne golfing papa                                            0.996988
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...      0.000174
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                               0.296185
#
#                                                                            danceability  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                0.613963
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                    0.874743
# 11m7laMUgmOKqI3oYzuhne golfing papa                                            0.664271
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...      0.749487
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                               0.722793
#
#                                                                            energy  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                             0.224
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                 0.517
# 11m7laMUgmOKqI3oYzuhne golfing papa                                         0.186
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...   0.798
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                            0.707
#
#                                                                            instrumentalness  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                    0.000523
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                        0.026426
# 11m7laMUgmOKqI3oYzuhne golfing papa                                                0.000018
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...          0.801802
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                                   0.000246
#
#                                                                            liveness  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                            0.379379
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                0.080981
# 11m7laMUgmOKqI3oYzuhne golfing papa                                        0.519520
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...  0.128128
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                           0.402402
#
#                                                                            loudness  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                            0.741868
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                0.825918
# 11m7laMUgmOKqI3oYzuhne golfing papa                                        0.750168
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...  0.825135
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                           0.845102
#
#                                                                            speechiness  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                               0.096395
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                   0.054995
# 11m7laMUgmOKqI3oYzuhne golfing papa                                           0.179197
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...     0.043769
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                              0.079094
#
#                                                                               tempo  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                            0.615900
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                0.356823
# 11m7laMUgmOKqI3oYzuhne golfing papa                                        0.400810
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...  0.525640
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                           0.501324
#
#                                                                            valence
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                             0.6340
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                 0.9500
# 11m7laMUgmOKqI3oYzuhne golfing papa                                         0.6890
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...   0.0422
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                            0.2990

# %%
indices = pd.Series(df_scaled.index.get_level_values(1))
indices
# Out:
# 0                                 keep a song in your soul
# 1                                     i put a spell on you
# 2                                             golfing papa
# 3        true house music - xavier santos & carlos gomi...
# 4                                                xuniverxe
#                                ...
# 84961                               yo no lloro por llorar
# 84962                            the secret life of plants
# 84963                        baby talks dirty - remastered
# 84964                                  lover's rock - edit
# 84965                                       paying on time
# Name: name, Length: 84966, dtype: object

# %% [markdown]
# # Cosine Similarity

# %%
#!free -m

# %%
#songs_1980s_genres = songs_1980s_up.dropna(subset=['genres'])
#songs_1980s_genres.genres.isna().value_counts()

# %%
#vect = CountVectorizer()
#X = vect.fit_transform(songs_1980s_genres['genres']) 
#X

# %%
#cosine_sim = cosine_similarity(X, X)
#cosine_sim

# %%
#Plug in all numerical values
songs_1980s_down_scaled = df_scaled[['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 
                                        'loudness', 'speechiness', 'tempo', 'valence']]

cosine_sim = cosine_similarity(songs_1980s_down_scaled, songs_1980s_down_scaled)

cosine_sim
# Out:
# array([[1.        , 0.9117561 , 0.9864706 , ..., 0.73203176, 0.89388984,
#         0.9563218 ],
#        [0.9117561 , 1.0000001 , 0.90904886, ..., 0.88289434, 0.90764034,
#         0.9653073 ],
#        [0.9864706 , 0.90904886, 0.99999994, ..., 0.70044184, 0.9049047 ,
#         0.93308896],
#        ...,
#        [0.73203176, 0.88289434, 0.70044184, ..., 1.0000001 , 0.8657574 ,
#         0.8509078 ],
#        [0.89388984, 0.90764034, 0.9049047 , ..., 0.8657574 , 1.        ,
#         0.9147182 ],
#        [0.9563218 , 0.96530735, 0.93308896, ..., 0.85090786, 0.91471815,
#         1.0000001 ]], dtype=float32)

# %%
def recommendations(name, cosine_sim=cosine_sim):
    #INPUT FOR ARTISTS RETURN LIST OF ARTISTS
    name = name.lower()
    idx = indices[indices == name].index[0]
    print(songs_1980s_down.iloc[idx][0])
    similarity_scores = list(enumerate(cosine_sim[idx]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similarity_scores = similarity_scores[1:6]
    
    songs_index = [i[0] for i in similarity_scores]
    
    return songs_1980s_down.iloc[songs_index]

# %%
recommendations('Let it be', cosine_sim)
# Out:
# John Denver
#                                                                                             artists  \
# id                     name
# 2NMznAoH3IluVA0Hyx1Or8 so long, farewell          Charmian Carr', 'Heather Menzies', 'Nicholas H...
# 1De9Vcb7o9L5cRYYFI7XbI sweet lorraine                                                  Wardell Gray
# 2G3xxspuPGxRQGTNwSyntS christmas wishes                                   The New Christy Minstrels
# 1FmaFrsU9Hy5tQUz6dPUmn take him                                Original Broadway Cast of 'Pal Joey'
# 48Mx6EFTaVF0meAMUfEWgG make yourself comfortable                                      Sarah Vaughan
#
#                                                   year  explicit  popularity  \
# id                     name
# 2NMznAoH3IluVA0Hyx1Or8 so long, farewell          1965         0          46
# 1De9Vcb7o9L5cRYYFI7XbI sweet lorraine             1953         0           2
# 2G3xxspuPGxRQGTNwSyntS christmas wishes           1963         0          11
# 1FmaFrsU9Hy5tQUz6dPUmn take him                   1952         0           7
# 48Mx6EFTaVF0meAMUfEWgG make yourself comfortable  1958         0          40
#
#                                                   duration_ms  acousticness  \
# id                     name
# 2NMznAoH3IluVA0Hyx1Or8 so long, farewell               173867         0.848
# 1De9Vcb7o9L5cRYYFI7XbI sweet lorraine                  245333         0.924
# 2G3xxspuPGxRQGTNwSyntS christmas wishes                111707         0.857
# 1FmaFrsU9Hy5tQUz6dPUmn take him                        185200         0.792
# 48Mx6EFTaVF0meAMUfEWgG make yourself comfortable       159560         0.870
#
#                                                   danceability  energy  \
# id                     name
# 2NMznAoH3IluVA0Hyx1Or8 so long, farewell                 0.528   0.153
# 1De9Vcb7o9L5cRYYFI7XbI sweet lorraine                    0.519   0.129
# 2G3xxspuPGxRQGTNwSyntS christmas wishes                  0.486   0.120
# 1FmaFrsU9Hy5tQUz6dPUmn take him                          0.450   0.127
# 48Mx6EFTaVF0meAMUfEWgG make yourself comfortable         0.526   0.125
#
#                                                   instrumentalness  liveness  \
# id                     name
# 2NMznAoH3IluVA0Hyx1Or8 so long, farewell                  0.000041     0.135
# 1De9Vcb7o9L5cRYYFI7XbI sweet lorraine                     0.006420     0.148
# 2G3xxspuPGxRQGTNwSyntS christmas wishes                   0.000000     0.124
# 1FmaFrsU9Hy5tQUz6dPUmn take him                           0.000000     0.183
# 48Mx6EFTaVF0meAMUfEWgG make yourself comfortable          0.000000     0.119
#
#                                                    loudness  mode key  \
# id                     name
# 2NMznAoH3IluVA0Hyx1Or8 so long, farewell         -16.398001     1  A#
# 1De9Vcb7o9L5cRYYFI7XbI sweet lorraine            -11.966000     0   D
# 2G3xxspuPGxRQGTNwSyntS christmas wishes          -16.521999     1   E
# 1FmaFrsU9Hy5tQUz6dPUmn take him                  -15.669000     1  D#
# 48Mx6EFTaVF0meAMUfEWgG make yourself comfortable -14.848000     0   E
#
#                                                   speechiness       tempo  \
# id                     name
# 2NMznAoH3IluVA0Hyx1Or8 so long, farewell               0.0497  119.674004
# 1De9Vcb7o9L5cRYYFI7XbI sweet lorraine                  0.0467  127.858002
# 2G3xxspuPGxRQGTNwSyntS christmas wishes                0.0363  117.293999
# 1FmaFrsU9Hy5tQUz6dPUmn take him                        0.0402  119.796997
# 48Mx6EFTaVF0meAMUfEWgG make yourself comfortable       0.0436  123.686996
#
#                                                   valence  \
# id                     name
# 2NMznAoH3IluVA0Hyx1Or8 so long, farewell            0.357
# 1De9Vcb7o9L5cRYYFI7XbI sweet lorraine               0.398
# 2G3xxspuPGxRQGTNwSyntS christmas wishes             0.334
# 1FmaFrsU9Hy5tQUz6dPUmn take him                     0.380
# 48Mx6EFTaVF0meAMUfEWgG make yourself comfortable    0.394
#
#                                                                                              genres
# id                     name
# 2NMznAoH3IluVA0Hyx1Or8 so long, farewell                                                        NaN
# 1De9Vcb7o9L5cRYYFI7XbI sweet lorraine                                 'cool jazz', 'jazz saxophone'
# 2G3xxspuPGxRQGTNwSyntS christmas wishes                 'american folk revival', 'traditional folk'
# 1FmaFrsU9Hy5tQUz6dPUmn take him
# 48Mx6EFTaVF0meAMUfEWgG make yourself comfortable  'adult standards', 'bebop', 'cool jazz', 'jazz...

# %% [markdown]
# # PCA with cosine similarity

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()
pca_fit = pca.fit_transform(df_scaled)
pca_fit
# Out:
# array([[ 0.3107919 , -0.17992392, -0.22775841, ...,  0.01252388,
#         -0.02054426, -0.04564155],
#        [ 0.07478655, -0.19177659, -0.06462984, ...,  0.13376063,
#          0.04404446, -0.05773644],
#        [ 0.21950923, -0.23024954, -0.08318975, ...,  0.07883651,
#          0.00971255,  0.01338098],
#        ...,
#        [ 1.2402827 ,  0.29129472,  0.1994881 , ..., -0.06730625,
#          0.03977066,  0.1383599 ],
#        [ 1.2547724 ,  0.34383297,  0.09320963, ...,  0.10359193,
#          0.0462822 ,  0.04212236],
#        [ 0.64561135, -0.32019687, -0.2276784 , ...,  0.06750678,
#         -0.03201765, -0.04989262]], dtype=float32)

# %%
cosine_sim = cosine_similarity(pca_fit, pca_fit)

cosine_sim
# Out:
# array([[1.0000001 , 0.67189544, 0.8946614 , ..., 0.47384453, 0.49406567,
#         0.86012316],
#        [0.67189544, 1.        , 0.8363348 , ..., 0.08221135, 0.07556417,
#         0.470967  ],
#        [0.8946614 , 0.8363348 , 0.9999999 , ..., 0.4146108 , 0.40392557,
#         0.8236787 ],
#        ...,
#        [0.47384453, 0.08221135, 0.4146108 , ..., 1.        , 0.9793997 ,
#         0.6516542 ],
#        [0.49406567, 0.07556417, 0.40392557, ..., 0.9793997 , 0.9999999 ,
#         0.68448013],
#        [0.86012316, 0.470967  , 0.8236787 , ..., 0.6516542 , 0.68448013,
#         1.0000001 ]], dtype=float32)

# %%
recommendations('One Time', cosine_sim)
# Out:
# Justin Bieber
#                                                                  artists  \
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                                   Bastille
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby      The Colourfield
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses        Dwight Yoakam
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered     Midnight Oil
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                          Pat Benatar
#
#                                                          year  explicit  \
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                            2013         0
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby      1985         0
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses      1987         0
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered  1987         0
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                      1981         0
#
#                                                          popularity  \
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                                    52
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby              35
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses              33
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered          55
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                              24
#
#                                                          duration_ms  \
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                                 225040
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby           142000
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses           130440
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered       311027
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                           210907
#
#                                                          acousticness  \
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                                 0.07120
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby           0.00715
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses           0.11700
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered       0.02820
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                           0.08150
#
#                                                          danceability  energy  \
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                                   0.583   0.778
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby             0.613   0.754
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses             0.669   0.813
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered         0.637   0.759
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                             0.575   0.694
#
#                                                          instrumentalness  \
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                                    0.000001
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby              0.000000
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses              0.000008
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered          0.000386
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                              0.018900
#
#                                                          liveness  loudness  \
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                              0.0753    -6.578
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby        0.0568    -9.961
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses        0.0692    -4.854
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered    0.0621   -11.004
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                        0.0740   -12.351
#
#                                                          mode key  \
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                               0   E
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby         1   C
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses         1   A
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered     1   G
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                         1   E
#
#                                                          speechiness  \
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                                 0.0459
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby           0.0392
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses           0.0398
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered       0.0295
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                           0.0500
#
#                                                               tempo  valence  \
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                            134.945007    0.673
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby      127.888000    0.688
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses      136.248993    0.721
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered  136.223007    0.686
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                      127.491997    0.659
#
#                                                                                                     genres
# id                     name
# 1xasoowGI2N5c4gykxKTlW icarus                            'metropopolis', 'modern rock', 'pop', 'pop roc...
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby      'dance rock', 'new romantic', 'new wave', 'new...
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses         'bakersfield sound', 'country', 'country rock'
# 7nfGP5B3Pc508kEb6zL6r9 the dead heart - 2007 remastered            'australian rock', 'dance rock', 'rock'
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                      'album rock', 'classic rock', 'dance rock', 'h...

# %% [markdown]
# # Euclidean Distance

# %%
from sklearn.metrics.pairwise import euclidean_distances

# %%
D = euclidean_distances(df_scaled, df_scaled)
D
# Out:
# array([[0.        , 0.36013266, 0.22136207, ..., 1.1583288 , 1.1515847 ,
#         0.42511165],
#        [0.36013266, 0.        , 0.21496494, ..., 1.3279524 , 1.334813  ,
#         0.6718846 ],
#        [0.22136207, 0.21496494, 0.        , ..., 1.1994582 , 1.2083106 ,
#         0.4972328 ],
#        ...,
#        [1.1583288 , 1.3279524 , 1.1994582 , ..., 0.        , 0.26563823,
#         0.9948124 ],
#        [1.1515847 , 1.334813  , 1.2083106 , ..., 0.26563823, 0.        ,
#         0.9652096 ],
#        [0.42511165, 0.6718846 , 0.4972328 , ..., 0.9948124 , 0.9652096 ,
#         0.        ]], dtype=float32)

# %%
def recommend_euclidean_distance(name):
    
    name = name.lower()

    idx = indices[indices == name].index[0]
    print(songs_1980s_down.iloc[idx][0])

    distance = list(enumerate(D[idx]))
    distance = sorted(distance, key=lambda x:x[1])
    distance = distance[1:6]
    
    songs_index = [i[0] for i in distance]
    
    return songs_1980s_down.iloc[songs_index]

# %%
recommend_euclidean_distance('One Time')
# Out:
# Justin Bieber
#                                                                                                    artists  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                                                                   Dua Lipa
# 645YBsxhFPSOKxGep3uHLv love maze                                                                       BTS
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                                                      Hombres G
# 1T20tqHKrePjszGOdbFOEd take a hint                       Victorious Cast', 'Victoria Justice', 'Elizabe...
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)                             Cobra Starship', 'Sabi
#
#                                                          year  explicit  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                          2020         0
# 645YBsxhFPSOKxGep3uHLv love maze                         2018         0
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien              1989         0
# 1T20tqHKrePjszGOdbFOEd take a hint                       2012         0
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)  2011         0
#
#                                                          popularity  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                                  81
# 645YBsxhFPSOKxGep3uHLv love maze                                 70
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                      56
# 1T20tqHKrePjszGOdbFOEd take a hint                               65
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)          68
#
#                                                          duration_ms  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                               193829
# 645YBsxhFPSOKxGep3uHLv love maze                              221529
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                   235467
# 1T20tqHKrePjszGOdbFOEd take a hint                            154000
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)       215693
#
#                                                          acousticness  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                               0.01370
# 645YBsxhFPSOKxGep3uHLv love maze                              0.04870
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                   0.04360
# 1T20tqHKrePjszGOdbFOEd take a hint                            0.00443
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)       0.01910
#
#                                                          danceability  energy  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                                 0.647   0.844
# 645YBsxhFPSOKxGep3uHLv love maze                                0.636   0.876
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                     0.663   0.840
# 1T20tqHKrePjszGOdbFOEd take a hint                              0.727   0.860
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)         0.668   0.857
#
#                                                          instrumentalness  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                                  0.000658
# 645YBsxhFPSOKxGep3uHLv love maze                                 0.000000
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                      0.000006
# 1T20tqHKrePjszGOdbFOEd take a hint                               0.000000
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)          0.000007
#
#                                                          liveness  loudness  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                            0.1020    -3.756
# 645YBsxhFPSOKxGep3uHLv love maze                           0.0728    -4.652
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                0.0491    -5.122
# 1T20tqHKrePjszGOdbFOEd take a hint                         0.0718    -2.712
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)    0.0385    -2.944
#
#                                                          mode key  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                             1   C
# 645YBsxhFPSOKxGep3uHLv love maze                            1   A
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                 1   C
# 1T20tqHKrePjszGOdbFOEd take a hint                          1  D#
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)     0   G
#
#                                                          speechiness  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                               0.0457
# 645YBsxhFPSOKxGep3uHLv love maze                              0.0617
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                   0.0434
# 1T20tqHKrePjszGOdbFOEd take a hint                            0.0641
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)       0.0535
#
#                                                               tempo  valence  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                          146.966995    0.746
# 645YBsxhFPSOKxGep3uHLv love maze                         149.932007    0.759
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien              148.018005    0.828
# 1T20tqHKrePjszGOdbFOEd take a hint                       133.994995    0.747
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)  131.959000    0.748
#
#                                                                                                     genres
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                                ['dance pop', 'pop', 'pop dance', 'uk pop']
# 645YBsxhFPSOKxGep3uHLv love maze                                              ['k-pop', 'k-pop boy group']
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien              ['latin', 'latin alternative', 'latin pop', 'l...
# 1T20tqHKrePjszGOdbFOEd take a hint                                                                     NaN
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)                                                NaN

# %% [markdown]
# # PCA with Euclidean Distance

# %%
pca = PCA()
pca_fit = pca.fit_transform(df_scaled)
pca_fit
# Out:
# array([[ 0.3107919 , -0.17992392, -0.22775841, ...,  0.01252388,
#         -0.02054426, -0.04564155],
#        [ 0.07478655, -0.19177659, -0.06462984, ...,  0.13376063,
#          0.04404446, -0.05773644],
#        [ 0.21950923, -0.23024954, -0.08318975, ...,  0.07883651,
#          0.00971255,  0.01338098],
#        ...,
#        [ 1.2402827 ,  0.29129472,  0.1994881 , ..., -0.06730625,
#          0.03977066,  0.1383599 ],
#        [ 1.2547724 ,  0.34383297,  0.09320963, ...,  0.10359193,
#          0.0462822 ,  0.04212236],
#        [ 0.64561135, -0.32019687, -0.2276784 , ...,  0.06750678,
#         -0.03201765, -0.04989262]], dtype=float32)

# %%
D = euclidean_distances(pca_fit, pca_fit)
D
# Out:
# array([[0.        , 0.3601475 , 0.22136883, ..., 1.1583242 , 1.1515802 ,
#         0.4251103 ],
#        [0.3601475 , 0.        , 0.21497284, ..., 1.3279537 , 1.3348145 ,
#         0.6718876 ],
#        [0.22136883, 0.21497284, 0.        , ..., 1.1994545 , 1.2083058 ,
#         0.4972303 ],
#        ...,
#        [1.1583242 , 1.3279537 , 1.1994545 , ..., 0.        , 0.2656383 ,
#         0.9948123 ],
#        [1.1515802 , 1.3348145 , 1.2083058 , ..., 0.2656383 , 0.        ,
#         0.9652094 ],
#        [0.4251103 , 0.6718876 , 0.4972303 , ..., 0.9948123 , 0.9652094 ,
#         0.        ]], dtype=float32)

# %%
recommend_euclidean_distance('One Time')
# Out:
# Justin Bieber
#                                                                                                    artists  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                                                                   Dua Lipa
# 645YBsxhFPSOKxGep3uHLv love maze                                                                       BTS
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                                                      Hombres G
# 1T20tqHKrePjszGOdbFOEd take a hint                       Victorious Cast', 'Victoria Justice', 'Elizabe...
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)                             Cobra Starship', 'Sabi
#
#                                                          year  explicit  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                          2020         0
# 645YBsxhFPSOKxGep3uHLv love maze                         2018         0
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien              1989         0
# 1T20tqHKrePjszGOdbFOEd take a hint                       2012         0
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)  2011         0
#
#                                                          popularity  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                                  81
# 645YBsxhFPSOKxGep3uHLv love maze                                 70
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                      56
# 1T20tqHKrePjszGOdbFOEd take a hint                               65
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)          68
#
#                                                          duration_ms  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                               193829
# 645YBsxhFPSOKxGep3uHLv love maze                              221529
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                   235467
# 1T20tqHKrePjszGOdbFOEd take a hint                            154000
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)       215693
#
#                                                          acousticness  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                               0.01370
# 645YBsxhFPSOKxGep3uHLv love maze                              0.04870
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                   0.04360
# 1T20tqHKrePjszGOdbFOEd take a hint                            0.00443
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)       0.01910
#
#                                                          danceability  energy  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                                 0.647   0.844
# 645YBsxhFPSOKxGep3uHLv love maze                                0.636   0.876
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                     0.663   0.840
# 1T20tqHKrePjszGOdbFOEd take a hint                              0.727   0.860
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)         0.668   0.857
#
#                                                          instrumentalness  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                                  0.000658
# 645YBsxhFPSOKxGep3uHLv love maze                                 0.000000
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                      0.000006
# 1T20tqHKrePjszGOdbFOEd take a hint                               0.000000
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)          0.000007
#
#                                                          liveness  loudness  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                            0.1020    -3.756
# 645YBsxhFPSOKxGep3uHLv love maze                           0.0728    -4.652
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                0.0491    -5.122
# 1T20tqHKrePjszGOdbFOEd take a hint                         0.0718    -2.712
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)    0.0385    -2.944
#
#                                                          mode key  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                             1   C
# 645YBsxhFPSOKxGep3uHLv love maze                            1   A
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                 1   C
# 1T20tqHKrePjszGOdbFOEd take a hint                          1  D#
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)     0   G
#
#                                                          speechiness  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                               0.0457
# 645YBsxhFPSOKxGep3uHLv love maze                              0.0617
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien                   0.0434
# 1T20tqHKrePjszGOdbFOEd take a hint                            0.0641
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)       0.0535
#
#                                                               tempo  valence  \
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                          146.966995    0.746
# 645YBsxhFPSOKxGep3uHLv love maze                         149.932007    0.759
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien              148.018005    0.828
# 1T20tqHKrePjszGOdbFOEd take a hint                       133.994995    0.747
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)  131.959000    0.748
#
#                                                                                                     genres
# id                     name
# 3AzjcOeAmA57TIOr9zF1ZW physical                                ['dance pop', 'pop', 'pop dance', 'uk pop']
# 645YBsxhFPSOKxGep3uHLv love maze                                              ['k-pop', 'k-pop boy group']
# 78FJd3BMjDQCA1Hh2QfKqS voy a pasármelo bien              ['latin', 'latin alternative', 'latin pop', 'l...
# 1T20tqHKrePjszGOdbFOEd take a hint                                                                     NaN
# 16Of7eeW44kt0a1M0nitHM you make me feel... (feat. sabi)                                                NaN

# %% [markdown]
# # Pearson Correlation

# %%
from scipy.stats import pearsonr

# %%
df_scaled_array = df_scaled.values
len(df_scaled_array)
# Out:
# 72230

# %%
def recommend_pearson(name):
    
    name = name.lower()
    idx = indices[indices == name].index[0]
    print(songs_1980s_up.iloc[idx][0])
    
    correlation = []
    
    for i in range(len(df_scaled_array)):
        correlation.append(pearsonr(df_scaled_array[idx], df_scaled_array[i]))
    
    correlation = list(enumerate(correlation))
    sorted_corr = sorted(correlation, reverse=True, key=lambda x: x[1])[1:6]
    print(sorted_corr)
    songs_index = [i[0] for i in sorted_corr]
    
    return songs_1980s_up.iloc[songs_index]

# %%
recommend_pearson('One time')
# Out:
# Justin Bieber
# C:\Users\vtkurt13\anaconda3\lib\site-packages\scipy\stats\stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# [(51165, (0.999095350754021, 7.325475206759157e-11)), (37702, (0.998830394100245, 1.7996229584610915e-10)), (30997, (0.9985649857545476, 3.6806771602588465e-10)), (49495, (0.9984579287843234, 4.734250825435821e-10)), (17020, (0.9984097751265599, 5.271938196960027e-10))]
#                                                                     artists  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                             Pat Benatar
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby         The Colourfield
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses           Dwight Yoakam
# 1xasoowGI2N5c4gykxKTlW icarus                                      Bastille
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered   The Lemonheads
#
#                                                             year  explicit  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                         1981         0
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby         1985         0
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses         1987         0
# 1xasoowGI2N5c4gykxKTlW icarus                               2013         0
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered  1992         0
#
#                                                             popularity  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                                 24
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby                 35
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses                 33
# 1xasoowGI2N5c4gykxKTlW icarus                                       52
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered          47
#
#                                                             duration_ms  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                              210907
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby              142000
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses              130440
# 1xasoowGI2N5c4gykxKTlW icarus                                    225040
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered       187040
#
#                                                             acousticness  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                              0.08150
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby              0.00715
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses              0.11700
# 1xasoowGI2N5c4gykxKTlW icarus                                    0.07120
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered       0.00164
#
#                                                             danceability  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                                0.575
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby                0.613
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses                0.669
# 1xasoowGI2N5c4gykxKTlW icarus                                      0.583
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered         0.645
#
#                                                             energy  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                          0.694
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby          0.754
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses          0.813
# 1xasoowGI2N5c4gykxKTlW icarus                                0.778
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered   0.792
#
#                                                             instrumentalness  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                                 0.018900
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby                 0.000000
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses                 0.000008
# 1xasoowGI2N5c4gykxKTlW icarus                                       0.000001
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered          0.000126
#
#                                                             liveness  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                           0.0740
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby           0.0568
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses           0.0692
# 1xasoowGI2N5c4gykxKTlW icarus                                 0.0753
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered    0.0799
#
#                                                             loudness  mode  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                          -12.351     1
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby           -9.961     1
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses           -4.854     1
# 1xasoowGI2N5c4gykxKTlW icarus                                 -6.578     0
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered    -8.671     1
#
#                                                            key  speechiness  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                          E       0.0500
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby          C       0.0392
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses          A       0.0398
# 1xasoowGI2N5c4gykxKTlW icarus                                E       0.0459
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered   A       0.0304
#
#                                                                  tempo  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                         127.491997
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby         127.888000
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses         136.248993
# 1xasoowGI2N5c4gykxKTlW icarus                               134.945007
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered  131.393005
#
#                                                             valence  \
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                           0.659
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby           0.688
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses           0.721
# 1xasoowGI2N5c4gykxKTlW icarus                                 0.673
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered    0.705
#
#                                                                                                        genres
# id                     name
# 2ZmYpqOpup0GhQ8CNXn4sW just like me                         ['album rock', 'classic rock', 'dance rock', '...
# 0oDabL89N3jO4qnGMANjAS can't get enough of you baby         ['dance rock', 'new romantic', 'new wave', 'ne...
# 6AdZANL6JwhLhj1WGKT31v always late with your kisses          ['bakersfield sound', 'country', 'country rock']
# 1xasoowGI2N5c4gykxKTlW icarus                               ['metropopolis', 'modern rock', 'pop', 'pop ro...
# 0ccE7u6mHbB1LaSc1ZIQWm it's a shame about ray - remastered  ['alternative pop', 'alternative rock', 'bosto...

# %%
song = songs_1980s_down.head(5)
song
# Out:
#                                                                                          artists  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                      Mamie Smith
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                Screamin' Jay Hawkins
# 11m7laMUgmOKqI3oYzuhne golfing papa                                                  Mamie Smith
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...        Oscar Velazquez
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                                            Mixe
#
#                                                                            year  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                            1920
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                1920
# 11m7laMUgmOKqI3oYzuhne golfing papa                                        1920
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...  1920
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                           1920
#
#                                                                            explicit  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                   0
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                       0
# 11m7laMUgmOKqI3oYzuhne golfing papa                                               0
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...         0
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                                  1
#
#                                                                            popularity  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                    12
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                         7
# 11m7laMUgmOKqI3oYzuhne golfing papa                                                 4
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...          17
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                                    2
#
#                                                                            duration_ms  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                 168333
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                     150200
# 11m7laMUgmOKqI3oYzuhne golfing papa                                             163827
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...       422087
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                                165224
#
#                                                                            acousticness  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                0.991000
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                    0.643000
# 11m7laMUgmOKqI3oYzuhne golfing papa                                            0.993000
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...      0.000173
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                               0.295000
#
#                                                                            danceability  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                   0.598
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                       0.852
# 11m7laMUgmOKqI3oYzuhne golfing papa                                               0.647
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...         0.730
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                                  0.704
#
#                                                                            energy  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                             0.224
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                 0.517
# 11m7laMUgmOKqI3oYzuhne golfing papa                                         0.186
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...   0.798
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                            0.707
#
#                                                                            instrumentalness  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                    0.000522
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                        0.026400
# 11m7laMUgmOKqI3oYzuhne golfing papa                                                0.000018
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...          0.801000
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                                   0.000246
#
#                                                                            liveness  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                              0.3790
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                  0.0809
# 11m7laMUgmOKqI3oYzuhne golfing papa                                          0.5190
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...    0.1280
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                             0.4020
#
#                                                                            loudness  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                             -12.628
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                  -7.261
# 11m7laMUgmOKqI3oYzuhne golfing papa                                         -12.098
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...    -7.311
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                             -6.036
#
#                                                                            mode  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                               0
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                   0
# 11m7laMUgmOKqI3oYzuhne golfing papa                                           1
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...     1
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                              0
#
#                                                                           key  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                             F
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                 F
# 11m7laMUgmOKqI3oYzuhne golfing papa                                         C
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...   D
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                           A#
#
#                                                                            speechiness  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                 0.0936
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                     0.0534
# 11m7laMUgmOKqI3oYzuhne golfing papa                                             0.1740
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...       0.0425
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                                0.0768
#
#                                                                                 tempo  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                            149.975998
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                 86.889000
# 11m7laMUgmOKqI3oYzuhne golfing papa                                         97.599998
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...  127.997002
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                           122.075996
#
#                                                                            valence  \
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                             0.6340
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                 0.9500
# 11m7laMUgmOKqI3oYzuhne golfing papa                                         0.6890
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...   0.0422
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                            0.2990
#
#                                                                                                               genres
# id                     name
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                            'harlem renaissance', 'traditional blues'
# 0hbkKFIJm7Z05H8Zl9w30f i put a spell on you                                             'blues', 'traditional blues'
# 11m7laMUgmOKqI3oYzuhne golfing papa                                        'harlem renaissance', 'traditional blues'
# 19Lc5SfJJ5O1oaxY0fpwfh true house music - xavier santos & carlos gomix...                                  'circuit'
# 2hJjbsLCytGsnAHfdsLejp xuniverxe                                                                        'glitchcore'

# %%
songs_1980s_down.index[1][1]
# Out:
# 'i put a spell on you'

# %%
indice = pd.Series(df_scaled.index.get_level_values(0))
indice
# Out:
# 0        0cS0A1fUEUd1EW3FcF8AEI
# 1        0hbkKFIJm7Z05H8Zl9w30f
# 2        11m7laMUgmOKqI3oYzuhne
# 3        19Lc5SfJJ5O1oaxY0fpwfh
# 4        2hJjbsLCytGsnAHfdsLejp
#                   ...
# 84961    1aG8WKumuYhKgHo8qsuq2K
# 84962    1eH0IlIt3QwY9ECkYD4osO
# 84963    1v64SrT0QJlpbrepnZOHPz
# 84964    260gWvS8Ae07oGVrhE3iVH
# 84965    2ChZ9Qm0BoT6A4QWIhg7c1
# Name: id, Length: 84966, dtype: object

# %%
def recommender(ids, cosine_sim=cosine_sim):
    
    
    idx = indice[indice == ids].index[0]

    similarity_scores = list(enumerate(cosine_sim[idx]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similarity_scores = similarity_scores[1:6]
    
    songs_index = [i[0] for i in similarity_scores]
    
    return songs_1980s_down.iloc[songs_index]

# %%
recommender('6fRpNQtnbNTdeUL30TbQgh', cosine_sim)
# Out:
#                                                                                                          artists  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                                                         Patti Page
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                                                      Mamie Smith
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                                                       Paul Simon
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody  Frank Loesser', 'Shorty Long', 'Susan Johnson'...
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli                                                         Pandya
#
#                                                                year  explicit  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                  1960         0
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                1920         0
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                1975         0
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody  1956         0
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli              1946         0
#
#                                                                popularity  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                          17
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                        12
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                        38
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody           4
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli                       0
#
#                                                                duration_ms  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                       191440
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                     168333
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                     329107
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody        86600
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli                   205894
#
#                                                                acousticness  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                         0.932
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                       0.991
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                       0.748
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody         0.873
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli                     0.990
#
#                                                                danceability  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                         0.589
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                       0.598
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                       0.469
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody         0.541
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli                     0.578
#
#                                                                energy  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                   0.275
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                 0.224
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                 0.223
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody   0.218
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli               0.274
#
#                                                                instrumentalness  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                          0.000000
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                        0.000522
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                        0.035500
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody          0.000007
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli                      0.000000
#
#                                                                liveness  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                     0.333
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                   0.379
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                   0.289
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody     0.347
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli                 0.346
#
#                                                                 loudness  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                 -11.375000
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul               -12.628000
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)               -18.556999
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody -14.802000
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli              -8.744000
#
#                                                                mode key  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                     1  A#
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                   0   F
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                   1  G#
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody     1   C
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli                 1   C
#
#                                                                speechiness  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                       0.0926
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                     0.0936
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                     0.0341
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody       0.0367
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli                   0.0796
#
#                                                                     tempo  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                  131.604004
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                149.975998
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                118.355003
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody  146.608994
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli              138.889008
#
#                                                                valence  \
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                    0.559
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                  0.634
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                  0.488
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody    0.551
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli                0.674
#
#                                                                                                           genres
# id                     name
# 5489YzOo19Ism2xHT5nUaG mister and mississippi                  'adult standards', 'brill building pop', 'deep...
# 0cS0A1fUEUd1EW3FcF8AEI keep a song in your soul                        'harlem renaissance', 'traditional blues'
# 79VmQuOW9aVJgydOwSWEH8 slip slidin' away (demo)                'classic rock', 'folk', 'folk rock', 'mellow g...
# 1xRD3CSAJwv0EJrXBtfxKA the most happy fella: i like ev'rybody                                                NaN
# 4svAFJF1Cbc2JDvhbyZcwk kyon ghungat mein athkheli                                                       'bhajan'

# %%
def create_top_5(song_df):
    #extract the songs with name id and artists with list of top 5 most similar songs
    df_song = pd.DataFrame(song_df['artists'])
    df_song.reset_index(inplace=True)
    df_song.set_index('id', inplace=True)
    top_5_dict = {}
    for i in range(len(song_df)):
        top_5 = {}
        recs = recommender(song_df.index[i][0], cosine_sim)
        for j in range(len(recs)):
            top_5[recs.index[j][0]] = recs.index[j][1], recs.iloc[j][0]
        top_5_dict[song_df.index[i][0]] = top_5
    top_5_series = pd.Series(top_5_dict)
    top_5_series.rename('top_5', inplace=True)
    top_5_songs_df = df_song.merge(top_5_series, how='inner', on=None, left_on=None, right_on=None, left_index=True, right_index=True)
    return top_5_songs_df

# %%
#top_5_1980s_up = create_top_5(songs_1980s_up)
#top_5__1980s_up

# %%
top_5_1980s_down = create_top_5(songs_1980s_down)
top_5_1980s_down
# Out:
#                                                                      name  \
# 0cS0A1fUEUd1EW3FcF8AEI                           keep a song in your soul
# 0hbkKFIJm7Z05H8Zl9w30f                               i put a spell on you
# 11m7laMUgmOKqI3oYzuhne                                       golfing papa
# 19Lc5SfJJ5O1oaxY0fpwfh  true house music - xavier santos & carlos gomi...
# 2hJjbsLCytGsnAHfdsLejp                                          xuniverxe
# ...                                                                   ...
# 1aG8WKumuYhKgHo8qsuq2K                             yo no lloro por llorar
# 1eH0IlIt3QwY9ECkYD4osO                          the secret life of plants
# 1v64SrT0QJlpbrepnZOHPz                      baby talks dirty - remastered
# 260gWvS8Ae07oGVrhE3iVH                                lover's rock - edit
# 2ChZ9Qm0BoT6A4QWIhg7c1                                     paying on time
#
#                                       artists  \
# 0cS0A1fUEUd1EW3FcF8AEI            Mamie Smith
# 0hbkKFIJm7Z05H8Zl9w30f  Screamin' Jay Hawkins
# 11m7laMUgmOKqI3oYzuhne            Mamie Smith
# 19Lc5SfJJ5O1oaxY0fpwfh        Oscar Velazquez
# 2hJjbsLCytGsnAHfdsLejp                   Mixe
# ...                                       ...
# 1aG8WKumuYhKgHo8qsuq2K        Diego Verdaguer
# 1eH0IlIt3QwY9ECkYD4osO          Stevie Wonder
# 1v64SrT0QJlpbrepnZOHPz              The Knack
# 260gWvS8Ae07oGVrhE3iVH              The Clash
# 2ChZ9Qm0BoT6A4QWIhg7c1     Hank Williams, Jr.
#
#                                                                     top_5
# 0cS0A1fUEUd1EW3FcF8AEI  {'6fRpNQtnbNTdeUL30TbQgh': ('my little cousin'...
# 0hbkKFIJm7Z05H8Zl9w30f  {'4DpBfWl3q8e0gGB76lAaox': ('fire on the mount...
# 11m7laMUgmOKqI3oYzuhne  {'7IAf9MvMze5Sj1vkmZid00': ('jyot se jyot jala...
# 19Lc5SfJJ5O1oaxY0fpwfh  {'0XvG24C6n5fcOvUEGrtuFR': ('the storm', 'Shun...
# 2hJjbsLCytGsnAHfdsLejp  {'2p7RcVGykyXz4xQZVuY6SZ': ('harold the barrel...
# ...                                                                   ...
# 1aG8WKumuYhKgHo8qsuq2K  {'6TRQUflD06zYvNijwb2HNH': ('i'm one', 'The Wh...
# 1eH0IlIt3QwY9ECkYD4osO  {'0fBXeZohJYNLmmBE5KPhnE': ('in taberna', 'Cor...
# 1v64SrT0QJlpbrepnZOHPz  {'1cyHl0dmSEeTexTKByPNJl': ('stop lookin' back...
# 260gWvS8Ae07oGVrhE3iVH  {'5VtrGJ5tD3dfWg5UDhP34W': ('burnin' and looti...
# 2ChZ9Qm0BoT6A4QWIhg7c1  {'2F2DaDQaGm04EbcDrpELyC': ('john henry', 'Bur...
#
# [84966 rows x 3 columns]

# %%
top_5_1980s_down[top_5_1980s_down['name'] == 'let it be']
# Out:
#                              name           artists  \
# 645PXX0qj8yLDBhS6bhuf4  let it be       John Denver
# 4vjNQBEWmeHP1M2fcWhSfA  let it be      Bill Withers
# 17TO3XH1slhDyqnwypne06  let it be        Joe Cocker
# 4uUDoZL1dOAXJsl3RSX1tX  let it be  Malvina Reynolds
# 4iu5Eu0fB9xMkVrBr9Kph4  let it be   Aretha Franklin
#
#                                                                     top_5
# 645PXX0qj8yLDBhS6bhuf4  {'2NMznAoH3IluVA0Hyx1Or8': ('so long, farewell...
# 4vjNQBEWmeHP1M2fcWhSfA  {'2WBwvFucTTCIIsSAwzl6P8': ('just you 'n' me',...
# 17TO3XH1slhDyqnwypne06  {'4p782fBH12AFlhNBz7x6pN': ('both sides now', ...
# 4uUDoZL1dOAXJsl3RSX1tX  {'1ygKcpsBAZ9wJsfUMVRHGp': ('soja soja nanhe r...
# 4iu5Eu0fB9xMkVrBr9Kph4  {'75J86PAeRywcLxjZrjdXjj': ('silver raven', 'G...

# %%
recommender('1kKvq34tmMVU0rWbxysJM6', cosine_sim)
# Out:
#                                                                                 artists  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                                      The Winans
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                                   R.L. Burnside
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                             Deceptikonz', 'P-Money
# 0W0eLsePQodsOy3IwY04BS provider                                                 N.E.R.D
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america        Gym Class Heroes
#
#                                                                  year  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                          1995
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                          1998
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                             2004
# 0W0eLsePQodsOy3IwY04BS provider                                  2002
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america  2005
#
#                                                                  explicit  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                                 0
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                                 0
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                                    0
# 0W0eLsePQodsOy3IwY04BS provider                                         1
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america         0
#
#                                                                  popularity  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                                  32
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                                  44
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                                     11
# 0W0eLsePQodsOy3IwY04BS provider                                          47
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america          69
#
#                                                                  duration_ms  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                               281227
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                               180467
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                                  303960
# 0W0eLsePQodsOy3IwY04BS provider                                       258670
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america       243773
#
#                                                                  acousticness  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                                 0.215
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                                 0.255
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                                    0.314
# 0W0eLsePQodsOy3IwY04BS provider                                         0.244
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america         0.237
#
#                                                                  danceability  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                                 0.684
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                                 0.769
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                                    0.690
# 0W0eLsePQodsOy3IwY04BS provider                                         0.697
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america         0.720
#
#                                                                  energy  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                           0.783
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                           0.680
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                              0.718
# 0W0eLsePQodsOy3IwY04BS provider                                   0.771
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america   0.744
#
#                                                                  instrumentalness  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                                      0.00
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                                      0.13
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                                         0.00
# 0W0eLsePQodsOy3IwY04BS provider                                              0.00
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america              0.00
#
#                                                                  liveness  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                             0.343
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                             0.325
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                                0.325
# 0W0eLsePQodsOy3IwY04BS provider                                     0.295
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america     0.255
#
#                                                                  loudness  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                            -5.602
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                            -9.731
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                               -8.505
# 0W0eLsePQodsOy3IwY04BS provider                                    -6.295
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america    -6.938
#
#                                                                  mode key  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                             0  A#
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                             1   G
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                                0  C#
# 0W0eLsePQodsOy3IwY04BS provider                                     0   B
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america     0  C#
#
#                                                                  speechiness  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                               0.1450
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                               0.0818
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                                  0.0928
# 0W0eLsePQodsOy3IwY04BS provider                                       0.0599
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america       0.1200
#
#                                                                      tempo  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                          87.040001
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                          95.986000
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                             92.317001
# 0W0eLsePQodsOy3IwY04BS provider                                  79.927002
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america  78.953003
#
#                                                                  valence  \
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                            0.540
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                            0.507
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                               0.551
# 0W0eLsePQodsOy3IwY04BS provider                                    0.617
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america    0.619
#
#                                                                                                             genres
# id                     name
# 5AcadSHX9HEKp4T7BSGAdE count it all joy                                                                   'gospel'
# 7tokOMPzSHbLJVZh8an2Nq let my baby ride                          'acoustic blues', 'blues', 'blues rock', 'coun...
# 6m0HpgS8s1bG1l7Zc8kWG4 fallen angels                                                                           NaN
# 0W0eLsePQodsOy3IwY04BS provider                                                      'hip hop', 'virginia hip hop'
# 2Lhdl74nwwVGOE2Gv35QuK cupid's chokehold / breakfast in america                             'dance pop', 'pop rap'

# %%
top_5_1980s_up.to_csv(r'C:\Users\vtkurt13\Springboard\CapstoneThreeKurstedt\Data\top_5_1980s_up.csv', index=True, header=True)

# %%
top_5_1980s_down.to_csv(r'C:\Users\vtkurt13\Springboard\CapstoneThreeKurstedt\Data\top_5_1980s_down.csv', index=True, header=True)
