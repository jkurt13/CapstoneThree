# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Link to function found in datacamp course
#https://campus.datacamp.com/courses/statistical-thinking-in-python-part-1/graphical-exploratory-data-analysis?ex=12
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# %%
#Gets the permutation means for columns
def get_perm_means(column):
    diff = []

    for i in range(10000):
        perm = np.random.permutation(songs_df[column])
        mean_diff = np.mean(perm[songs_df['mode'] == 0]) - np.mean(perm[songs_df['mode'] == 1])
        diff.append(mean_diff)
    return diff

# %%
#Hypothesis testing for p values
def hypo_test(column, diff):
    pos_extreme = []
    neg_extreme = []
    major_song = song_major[column]
    minor_song = song_minor[column]
    song_obs = np.mean(major_song) - np.mean(minor_song)
    song_obs = abs(song_obs)
    

    for j in range(len(diff)):
        if(diff[j] >= song_obs):
            pos_extreme.append(diff[j])
        elif(diff[j] <= -song_obs):
            neg_extreme.append(diff[j])
    return (len(pos_extreme), len(neg_extreme))

# %%
songs_df = pd.read_csv('Data/songs_w_genres_df.csv', index_col='id')
songs_df.head()
# Out:
#                                                                      name  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI                           Keep A Song In Your Soul
# 0hbkKFIJm7Z05H8Zl9w30f                               I Put A Spell On You
# 11m7laMUgmOKqI3oYzuhne                                       Golfing Papa
# 19Lc5SfJJ5O1oaxY0fpwfh  True House Music - Xavier Santos & Carlos Gomi...
# 2hJjbsLCytGsnAHfdsLejp                                          Xuniverxe
#
#                                       artists  year  explicit  popularity  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI            Mamie Smith  1920         0          12
# 0hbkKFIJm7Z05H8Zl9w30f  Screamin' Jay Hawkins  1920         0           7
# 11m7laMUgmOKqI3oYzuhne            Mamie Smith  1920         0           4
# 19Lc5SfJJ5O1oaxY0fpwfh        Oscar Velazquez  1920         0          17
# 2hJjbsLCytGsnAHfdsLejp                   Mixe  1920         1           2
#
#                         duration_ms  acousticness  danceability  energy  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI       168333      0.991000         0.598   0.224
# 0hbkKFIJm7Z05H8Zl9w30f       150200      0.643000         0.852   0.517
# 11m7laMUgmOKqI3oYzuhne       163827      0.993000         0.647   0.186
# 19Lc5SfJJ5O1oaxY0fpwfh       422087      0.000173         0.730   0.798
# 2hJjbsLCytGsnAHfdsLejp       165224      0.295000         0.704   0.707
#
#                         instrumentalness  liveness  loudness  mode key  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI          0.000522    0.3790   -12.628     0   F
# 0hbkKFIJm7Z05H8Zl9w30f          0.026400    0.0809    -7.261     0   F
# 11m7laMUgmOKqI3oYzuhne          0.000018    0.5190   -12.098     1   C
# 19Lc5SfJJ5O1oaxY0fpwfh          0.801000    0.1280    -7.311     1   D
# 2hJjbsLCytGsnAHfdsLejp          0.000246    0.4020    -6.036     0  A#
#
#                         speechiness    tempo  valence  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI       0.0936  149.976   0.6340
# 0hbkKFIJm7Z05H8Zl9w30f       0.0534   86.889   0.9500
# 11m7laMUgmOKqI3oYzuhne       0.1740   97.600   0.6890
# 19Lc5SfJJ5O1oaxY0fpwfh       0.0425  127.997   0.0422
# 2hJjbsLCytGsnAHfdsLejp       0.0768  122.076   0.2990
#
#                                                              genres
# id
# 0cS0A1fUEUd1EW3FcF8AEI  ['harlem renaissance', 'traditional blues']
# 0hbkKFIJm7Z05H8Zl9w30f               ['blues', 'traditional blues']
# 11m7laMUgmOKqI3oYzuhne  ['harlem renaissance', 'traditional blues']
# 19Lc5SfJJ5O1oaxY0fpwfh                                  ['circuit']
# 2hJjbsLCytGsnAHfdsLejp                               ['glitchcore']

# %%
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 174389 entries, 0cS0A1fUEUd1EW3FcF8AEI to 57tgYkWQTNHVFEt6xDKKZj
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              174389 non-null  object
#  1   artists           174389 non-null  object
#  2   year              174389 non-null  int64
#  3   explicit          174389 non-null  int64
#  4   popularity        174389 non-null  int64
#  5   duration_ms       174389 non-null  int64
#  6   acousticness      174389 non-null  float64
#  7   danceability      174389 non-null  float64
#  8   energy            174389 non-null  float64
#  9   instrumentalness  174389 non-null  float64
#  10  liveness          174389 non-null  float64
#  11  loudness          174389 non-null  float64
#  12  mode              174389 non-null  int64
#  13  key               174389 non-null  object
#  14  speechiness       174389 non-null  float64
#  15  tempo             174389 non-null  float64
#  16  valence           174389 non-null  float64
#  17  genres            137418 non-null  object
# dtypes: float64(9), int64(5), object(4)
# memory usage: 25.3+ MB

# %%
no_genre_df = songs_df.dropna(subset=['genres'])
no_genre_df = no_genre_df[no_genre_df['genres'] != '[]']

# %%
no_genre_df.sort_values(by='popularity', ascending=True).head(10)
# Out:
#                                                   name  \
# id
# 2y9jSsUKlrCMPAYphaNoDt        Something Going On Wrong
# 0d3XPvr9Xrb8kC64zzBJnf                Someone Like You
# 2nF6AMAAhcqQ9A6Lzd3R5u                            True
# 18enZNvTk5Ks85Qyp4eHZs       Beyond the Forest Part. 3
# 19Hb2Qx1SMvTeOXCnXqMMB        Nerdesin Bilmem Ne Oldun
# 1ADljX6Q1nqgJS3rJvEYLg             Kajal Kali Raatladi
# 1AN8e6gRDQ6dECn5engJgV            Dil Bar Bar Ghabraye
# 1Bc33rymITWntDSD2XdfhK     Aji Sambhal Ke Aana Ho Lala
# 1Bo8VjSzkP8qu6fJ51fErB  Piano Quartet: I. Adagio serio
# 17wIkhwf29IUKCGKuOv39H                Kahti Hai Jawani
#
#                                        artists  year  explicit  popularity  \
# id
# 2y9jSsUKlrCMPAYphaNoDt  Sonny Boy Williamson I  1941         0           0
# 0d3XPvr9Xrb8kC64zzBJnf         Fred Everything  2021         0           0
# 2nF6AMAAhcqQ9A6Lzd3R5u         Fred Everything  2021         0           0
# 18enZNvTk5Ks85Qyp4eHZs             Max Steiner  1949         0           0
# 19Hb2Qx1SMvTeOXCnXqMMB             Safiye Ayla  1949         0           0
# 1ADljX6Q1nqgJS3rJvEYLg            Meena Kapoor  1949         0           0
# 1AN8e6gRDQ6dECn5engJgV              Geeta Dutt  1949         0           0
# 1Bc33rymITWntDSD2XdfhK         Lata Mangeshkar  1949         0           0
# 1Bo8VjSzkP8qu6fJ51fErB           Aaron Copland  1949         0           0
# 17wIkhwf29IUKCGKuOv39H             Asha Bhosle  1949         0           0
#
#                         duration_ms  acousticness  danceability  energy  \
# id
# 2y9jSsUKlrCMPAYphaNoDt       190250      0.995000         0.480  0.0543
# 0d3XPvr9Xrb8kC64zzBJnf       349130      0.000018         0.757  0.8290
# 2nF6AMAAhcqQ9A6Lzd3R5u       330828      0.000221         0.617  0.9490
# 18enZNvTk5Ks85Qyp4eHZs       320209      0.599000         0.121  0.3440
# 19Hb2Qx1SMvTeOXCnXqMMB       159681      0.995000         0.372  0.6270
# 1ADljX6Q1nqgJS3rJvEYLg       167921      0.995000         0.884  0.0560
# 1AN8e6gRDQ6dECn5engJgV       170096      0.995000         0.453  0.1090
# 1Bc33rymITWntDSD2XdfhK       167941      0.817000         0.748  0.3350
# 1Bo8VjSzkP8qu6fJ51fErB       402373      0.917000         0.166  0.1080
# 17wIkhwf29IUKCGKuOv39H       194105      0.994000         0.856  0.0815
#
#                         instrumentalness  liveness  loudness  mode key  \
# id
# 2y9jSsUKlrCMPAYphaNoDt          0.251000    0.1310   -20.844     1   G
# 0d3XPvr9Xrb8kC64zzBJnf          0.879000    0.4530   -10.178     0  F#
# 2nF6AMAAhcqQ9A6Lzd3R5u          0.888000    0.0663    -9.297     0   D
# 18enZNvTk5Ks85Qyp4eHZs          0.692000    0.1510   -10.891     1   C
# 19Hb2Qx1SMvTeOXCnXqMMB          0.948000    0.2170   -14.060     0   A
# 1ADljX6Q1nqgJS3rJvEYLg          0.567000    0.1210   -12.246     0  A#
# 1AN8e6gRDQ6dECn5engJgV          0.414000    0.1070   -15.331     0  D#
# 1Bc33rymITWntDSD2XdfhK          0.000000    0.2000    -9.007     1   E
# 1Bo8VjSzkP8qu6fJ51fErB          0.111000    0.0844   -17.932     0  A#
# 17wIkhwf29IUKCGKuOv39H          0.000743    0.1300    -8.332     1  D#
#
#                         speechiness    tempo  valence  \
# id
# 2y9jSsUKlrCMPAYphaNoDt       0.0997   77.890   0.5710
# 0d3XPvr9Xrb8kC64zzBJnf       0.0499  120.003   0.3140
# 2nF6AMAAhcqQ9A6Lzd3R5u       0.0456  121.994   0.7520
# 18enZNvTk5Ks85Qyp4eHZs       0.0336   76.567   0.0917
# 19Hb2Qx1SMvTeOXCnXqMMB       0.3820   77.469   0.3870
# 1ADljX6Q1nqgJS3rJvEYLg       0.4380  106.596   0.7770
# 1AN8e6gRDQ6dECn5engJgV       0.0965  168.885   0.4850
# 1Bc33rymITWntDSD2XdfhK       0.0753  133.438   0.8940
# 1Bo8VjSzkP8qu6fJ51fErB       0.0356   82.727   0.0375
# 17wIkhwf29IUKCGKuOv39H       0.2170  128.306   0.7910
#
#                                                                    genres
# id
# 2y9jSsUKlrCMPAYphaNoDt  ['acoustic blues', 'blues', 'chicago blues', '...
# 0d3XPvr9Xrb8kC64zzBJnf                                     ['deep house']
# 2nF6AMAAhcqQ9A6Lzd3R5u                                     ['deep house']
# 18enZNvTk5Ks85Qyp4eHZs                             ['classic soundtrack']
# 19Hb2Qx1SMvTeOXCnXqMMB              ['turkish classical', 'turkish jazz']
# 1ADljX6Q1nqgJS3rJvEYLg                              ['classic bollywood']
# 1AN8e6gRDQ6dECn5engJgV  ['classic bollywood', 'classic pakistani pop',...
# 1Bc33rymITWntDSD2XdfhK  ['classic bollywood', 'desi pop', 'filmi', 'su...
# 1Bo8VjSzkP8qu6fJ51fErB  ['american modern classical', 'classical', 'ea...
# 17wIkhwf29IUKCGKuOv39H  ['chutney', 'classic bollywood', 'desi pop', '...

# %%
songs_df.sort_values(by='popularity', ascending=False).head(10)
# Out:
#                                           name                   artists  \
# id
# 7lPN2DXiMsVn7XUKtOW1CS         drivers license            Olivia Rodrigo
# 3tjFYV6RSFtuktYl3ZtYcq  Mood (feat. iann dior)     24kGoldn', 'iann dior
# 35mvY5S1H3J2QZyna3TFe0               positions             Ariana Grande
# 47EiUVwUp4C9fGccaPuUCS                  DÁKITI  Bad Bunny', 'Jhay Cortez
# 7vrJn5hDSXRmdXoR30KgF1                 BICHOTA                   KAROL G
# 6Im9k8u9iIzKMrmV7BWtlF                   34+35             Ariana Grande
# 5vGLcdRuSbUhD8ScwsGSdA                 Whoopty                        CJ
# 27OeeYzk6klgBh83TSvGMA             WITHOUT YOU             The Kid LAROI
# 54bFM56PmE4YLRnqpW6Tha          Therefore I Am             Billie Eilish
# 2XIc1pqjXV3Cr2BQUGNBck      LA NOCHE DE ANOCHE      Bad Bunny', 'ROSALÍA
#
#                         year  explicit  popularity  duration_ms  acousticness  \
# id
# 7lPN2DXiMsVn7XUKtOW1CS  2021         1         100       242014        0.7210
# 3tjFYV6RSFtuktYl3ZtYcq  2020         1          96       140526        0.2210
# 35mvY5S1H3J2QZyna3TFe0  2020         1          96       172325        0.4680
# 47EiUVwUp4C9fGccaPuUCS  2020         1          95       205090        0.4010
# 7vrJn5hDSXRmdXoR30KgF1  2020         1          95       178947        0.2120
# 6Im9k8u9iIzKMrmV7BWtlF  2020         1          94       173711        0.2370
# 5vGLcdRuSbUhD8ScwsGSdA  2020         1          94       123429        0.1900
# 27OeeYzk6klgBh83TSvGMA  2020         1          94       161385        0.2130
# 54bFM56PmE4YLRnqpW6Tha  2020         0          94       174321        0.2180
# 2XIc1pqjXV3Cr2BQUGNBck  2020         0          94       203201        0.0303
#
#                         danceability  energy  instrumentalness  liveness  \
# id
# 7lPN2DXiMsVn7XUKtOW1CS         0.585   0.436          0.000013    0.1050
# 3tjFYV6RSFtuktYl3ZtYcq         0.700   0.722          0.000000    0.2720
# 35mvY5S1H3J2QZyna3TFe0         0.737   0.802          0.000000    0.0931
# 47EiUVwUp4C9fGccaPuUCS         0.731   0.573          0.000052    0.1130
# 7vrJn5hDSXRmdXoR30KgF1         0.863   0.666          0.000493    0.1030
# 6Im9k8u9iIzKMrmV7BWtlF         0.830   0.585          0.000000    0.2480
# 5vGLcdRuSbUhD8ScwsGSdA         0.711   0.598          0.000000    0.1500
# 27OeeYzk6klgBh83TSvGMA         0.662   0.413          0.000000    0.1340
# 54bFM56PmE4YLRnqpW6Tha         0.889   0.340          0.130000    0.0550
# 2XIc1pqjXV3Cr2BQUGNBck         0.856   0.618          0.000000    0.0866
#
#                         loudness  mode key  speechiness    tempo  valence  \
# id
# 7lPN2DXiMsVn7XUKtOW1CS    -8.761     1  A#       0.0601  143.874    0.132
# 3tjFYV6RSFtuktYl3ZtYcq    -3.558     0   G       0.0369   90.989    0.756
# 35mvY5S1H3J2QZyna3TFe0    -4.771     1   C       0.0878  144.015    0.682
# 47EiUVwUp4C9fGccaPuUCS   -10.059     0   E       0.0544  109.928    0.145
# 7vrJn5hDSXRmdXoR30KgF1    -4.158     0  C#       0.1520  163.908    0.838
# 6Im9k8u9iIzKMrmV7BWtlF    -6.476     1   C       0.0940  109.978    0.485
# 5vGLcdRuSbUhD8ScwsGSdA    -7.621     0  D#       0.1820  140.175    0.737
# 27OeeYzk6klgBh83TSvGMA    -7.357     1   C       0.0299   93.005    0.467
# 54bFM56PmE4YLRnqpW6Tha    -7.773     0   B       0.0697   94.009    0.716
# 2XIc1pqjXV3Cr2BQUGNBck    -4.892     1   G       0.2860   81.993    0.391
#
#                                                                    genres
# id
# 7lPN2DXiMsVn7XUKtOW1CS                           ['pop', 'post-teen pop']
# 3tjFYV6RSFtuktYl3ZtYcq                                                NaN
# 35mvY5S1H3J2QZyna3TFe0              ['dance pop', 'pop', 'post-teen pop']
# 47EiUVwUp4C9fGccaPuUCS                                                NaN
# 7vrJn5hDSXRmdXoR30KgF1  ['latin', 'reggaeton', 'reggaeton colombiano',...
# 6Im9k8u9iIzKMrmV7BWtlF              ['dance pop', 'pop', 'post-teen pop']
# 5vGLcdRuSbUhD8ScwsGSdA                                                 []
# 27OeeYzk6klgBh83TSvGMA                             ['australian hip hop']
# 54bFM56PmE4YLRnqpW6Tha                              ['electropop', 'pop']
# 2XIc1pqjXV3Cr2BQUGNBck                                                NaN

# %%
songs_df.describe()
# Out:
#                 year       explicit     popularity   duration_ms  \
# count  174389.000000  174389.000000  174389.000000  1.743890e+05
# mean     1977.061764       0.068135      25.693381  2.328100e+05
# std        26.907950       0.251978      21.872740  1.483958e+05
# min      1920.000000       0.000000       0.000000  4.937000e+03
# 25%      1955.000000       0.000000       1.000000  1.661330e+05
# 50%      1977.000000       0.000000      25.000000  2.057870e+05
# 75%      1999.000000       0.000000      42.000000  2.657200e+05
# max      2021.000000       1.000000     100.000000  5.338302e+06
#
#         acousticness   danceability         energy  instrumentalness  \
# count  174389.000000  174389.000000  174389.000000     174389.000000
# mean        0.499228       0.536758       0.482721          0.197252
# std         0.379936       0.176025       0.272685          0.334574
# min         0.000000       0.000000       0.000000          0.000000
# 25%         0.087700       0.414000       0.249000          0.000000
# 50%         0.517000       0.548000       0.465000          0.000524
# 75%         0.895000       0.669000       0.711000          0.252000
# max         0.996000       0.988000       1.000000          1.000000
#
#             liveness       loudness           mode    speechiness  \
# count  174389.000000  174389.000000  174389.000000  174389.000000
# mean        0.211123     -11.750865       0.702384       0.105729
# std         0.180493       5.691591       0.457211       0.182260
# min         0.000000     -60.000000       0.000000       0.000000
# 25%         0.099200     -14.908000       0.000000       0.035200
# 50%         0.138000     -10.836000       1.000000       0.045500
# 75%         0.270000      -7.499000       1.000000       0.076300
# max         1.000000       3.855000       1.000000       0.971000
#
#                tempo        valence
# count  174389.000000  174389.000000
# mean      117.006500       0.524533
# std        30.254178       0.264477
# min         0.000000       0.000000
# 25%        93.931000       0.311000
# 50%       115.816000       0.536000
# 75%       135.011000       0.743000
# max       243.507000       1.000000

# %%
songs_df['key'].value_counts()
# Out:
# C     21967
# G     21363
# D     18916
# A     18109
# F     16546
# C#    13562
# E     13327
# A#    12406
# B     11014
# G#    10673
# F#     9226
# D#     7280
# Name: key, dtype: int64

# %%
numerical_songs = songs_df.select_dtypes(include=['int64', 'float64'])
numerical_songs.head()
# Out:
#                         year  explicit  popularity  duration_ms  acousticness  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI  1920         0          12       168333      0.991000
# 0hbkKFIJm7Z05H8Zl9w30f  1920         0           7       150200      0.643000
# 11m7laMUgmOKqI3oYzuhne  1920         0           4       163827      0.993000
# 19Lc5SfJJ5O1oaxY0fpwfh  1920         0          17       422087      0.000173
# 2hJjbsLCytGsnAHfdsLejp  1920         1           2       165224      0.295000
#
#                         danceability  energy  instrumentalness  liveness  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI         0.598   0.224          0.000522    0.3790
# 0hbkKFIJm7Z05H8Zl9w30f         0.852   0.517          0.026400    0.0809
# 11m7laMUgmOKqI3oYzuhne         0.647   0.186          0.000018    0.5190
# 19Lc5SfJJ5O1oaxY0fpwfh         0.730   0.798          0.801000    0.1280
# 2hJjbsLCytGsnAHfdsLejp         0.704   0.707          0.000246    0.4020
#
#                         loudness  mode  speechiness    tempo  valence
# id
# 0cS0A1fUEUd1EW3FcF8AEI   -12.628     0       0.0936  149.976   0.6340
# 0hbkKFIJm7Z05H8Zl9w30f    -7.261     0       0.0534   86.889   0.9500
# 11m7laMUgmOKqI3oYzuhne   -12.098     1       0.1740   97.600   0.6890
# 19Lc5SfJJ5O1oaxY0fpwfh    -7.311     1       0.0425  127.997   0.0422
# 2hJjbsLCytGsnAHfdsLejp    -6.036     0       0.0768  122.076   0.2990

# %%
_ = numerical_songs.hist(figsize=(15,10))
_ = plt.subplots_adjust(hspace=0.5)
plt.show()

# %%
numerical_songs.groupby(by='mode').mean()
# Out:
#              year  explicit  popularity    duration_ms  acousticness  \
# mode
# 0     1979.084064  0.092330   25.436254  243490.339473      0.461504
# 1     1976.204869  0.057883   25.802332  228284.538616      0.515213
#
#       danceability    energy  instrumentalness  liveness   loudness  \
# mode
# 0         0.549834  0.506247          0.226411  0.210658 -11.582547
# 1         0.531217  0.472752          0.184897  0.211320 -11.822185
#
#       speechiness       tempo  valence
# mode
# 0        0.117128  116.893193  0.51576
# 1        0.100899  117.054511  0.52825

# %%
song_major = songs_df[songs_df['mode'] == 1]
song_minor = songs_df[songs_df['mode'] == 0]

# %% [markdown]
# # Acousticness

# %%
plt.figure(figsize=(20,10))

sns.set_theme(style='whitegrid')
ax = sns.violinplot(x='mode', y='acousticness', hue='key', data=songs_df)

# %%
x_yard, y_yard = ecdf(songs_df['acousticness'])

_ = plt.plot(x_yard, y_yard, marker='.', linestyle='none')

_ = plt.xlabel('Acousticness')
_ = plt.ylabel('ECDF')

# %%
diff_acoustic = get_perm_means('acousticness')
_ = plt.hist(diff_acoustic)
_ = plt.xlabel('Difference in Means')
_ = plt.ylabel('Count')

# %%
results_acoustic = hypo_test('acousticness', diff_acoustic)
results_acoustic
# Out:
# (0, 0)

# %% [markdown]
# # Danceability

# %%
plt.figure(figsize=(20,10))

sns.set_theme(style='whitegrid')
ax = sns.violinplot(x='mode', y='danceability', hue='explicit', data=songs_df, split=True)

# %%
x_yard, y_yard = ecdf(songs_df['danceability'])

_ = plt.plot(x_yard, y_yard, marker='.', linestyle='none')

_ = plt.xlabel('Danceability')
_ = plt.ylabel('ECDF')

# %%
diff_dance = get_perm_means('danceability')
_ = plt.hist(diff_dance)
_ = plt.xlabel('Difference in Means')
_ = plt.ylabel('Count')

# %%
results_dance = hypo_test('danceability', diff_dance)
results_dance
# Out:
# (0, 0)

# %% [markdown]
# # Energy

# %%
plt.figure(figsize=(20,10))

sns.set_theme(style='whitegrid')
ax = sns.violinplot(x='mode', y='energy', hue='explicit', data=songs_df, split=True)

# %%
x_yard, y_yard = ecdf(songs_df['energy'])

_ = plt.plot(x_yard, y_yard, marker='.', linestyle='none')

_ = plt.xlabel('Energy')
_ = plt.ylabel('ECDF')

# %%
diff_energy = get_perm_means('energy')
_ = plt.hist(diff_energy)
_ = plt.xlabel('Difference in Means')
_ = plt.ylabel('Count')

# %%
results_energy = hypo_test('energy', diff_energy)
results_energy
# Out:
# (0, 0)

# %% [markdown]
# # Instrumentalness

# %%
plt.figure(figsize=(20,10))

sns.set_theme(style='whitegrid')
ax = sns.violinplot(x='mode', y='instrumentalness', hue='explicit', data=songs_df, split=True)

# %%
x_yard, y_yard = ecdf(songs_df['instrumentalness'])

_ = plt.plot(x_yard, y_yard, marker='.', linestyle='none')

_ = plt.xlabel('Instrumentalness')
_ = plt.ylabel('ECDF')

# %%
diff_instrument = get_perm_means('instrumentalness')
_ = plt.hist(diff_instrument)
_ = plt.xlabel('Difference in Means')
_ = plt.ylabel('Count')

# %%
results_instrument = hypo_test('instrumentalness', diff_instrument)
results_instrument
# Out:
# (0, 0)

# %% [markdown]
# # Loudness

# %%
plt.figure(figsize=(20,10))

sns.set_theme(style='whitegrid')
ax = sns.violinplot(x='mode', y='loudness', hue='explicit', data=songs_df, split=True)

# %%
x_yard, y_yard = ecdf(songs_df['loudness'])

_ = plt.plot(x_yard, y_yard, marker='.', linestyle='none')

_ = plt.xlabel('Loudness')
_ = plt.ylabel('ECDF')

# %%
diff_loud = get_perm_means('loudness')
_ = plt.hist(diff_loud)
_ = plt.xlabel('Difference in Means')
_ = plt.ylabel('Count')

# %%
results_loud = hypo_test('loudness', diff_loud)
results_loud
# Out:
# (0, 0)

# %% [markdown]
# # Popularity

# %%
plt.figure(figsize=(20,10))

sns.set_theme(style='whitegrid')
ax = sns.violinplot(x='mode', y='popularity', hue='explicit', data=songs_df, split=True)

# %%
x_yard, y_yard = ecdf(songs_df['popularity'])

_ = plt.plot(x_yard, y_yard, marker='.', linestyle='none')

_ = plt.xlabel('Popularity')
_ = plt.ylabel('ECDF')

# %%
diff_pop = get_perm_means('popularity')
_ = plt.hist(diff_pop)
_ = plt.xlabel('Difference in Means')
_ = plt.ylabel('Count')

# %%
results_pop = hypo_test('popularity', diff_pop)
results_pop
# Out:
# (9, 11)

# %% [markdown]
# # Speechiness

# %%
plt.figure(figsize=(20,10))

sns.set_theme(style='whitegrid')
ax = sns.violinplot(x='mode', y='speechiness', hue='explicit', data=songs_df, split=True)

# %%
x_yard, y_yard = ecdf(songs_df['speechiness'])

_ = plt.plot(x_yard, y_yard, marker='.', linestyle='none')

_ = plt.xlabel('Speechiness')
_ = plt.ylabel('ECDF')

# %%
diff_speech = get_perm_means('speechiness')
_ = plt.hist(diff_speech)
_ = plt.xlabel('Difference in Means')
_ = plt.ylabel('Count')

# %%
results_speech = hypo_test('speechiness', diff_speech)
results_speech
# Out:
# (0, 0)

# %% [markdown]
# # Tempo

# %%
plt.figure(figsize=(20,10))

sns.set_theme(style='whitegrid')
ax = sns.violinplot(x='mode', y='tempo', hue='explicit', data=songs_df, split=True)

# %%
x_yard, y_yard = ecdf(songs_df['tempo'])

_ = plt.plot(x_yard, y_yard, marker='.', linestyle='none')

_ = plt.xlabel('Tempo')
_ = plt.ylabel('ECDF')

# %%
diff_tempo = get_perm_means('tempo')
_ = plt.hist(diff_tempo)
_ = plt.xlabel('Difference in Means')
_ = plt.ylabel('Count')

# %%
results_tempo = hypo_test('tempo', diff_tempo)
results_tempo
# Out:
# (1490, 1582)

# %% [markdown]
# # Valence

# %%
plt.figure(figsize=(20,10))

sns.set_theme(style='whitegrid')
ax = sns.violinplot(x='mode', y='valence', hue='explicit', data=songs_df, split=True)

# %%
x_yard, y_yard = ecdf(songs_df['valence'])

_ = plt.plot(x_yard, y_yard, marker='.', linestyle='none')

_ = plt.xlabel('Valence')
_ = plt.ylabel('ECDF')

# %%
diff_valence = get_perm_means('valence')
_ = plt.hist(diff_valence)
_ = plt.xlabel('Difference in Means')
_ = plt.ylabel('Count')

# %%
results_valence = hypo_test('valence', diff_valence)
results_valence
# Out:
# (0, 0)

# %% [markdown]
# # HeatMap

# %%
plt.figure(figsize=(20,10))
_ = sns.heatmap(songs_df.corr(), annot=True)

# %%
sns.histplot(songs_df, x='popularity', stat='count', bins=10)

# %%
sns.histplot(songs_df, x='year', hue='mode', stat='count', bins=10)

# %%
sns.set_theme(style='ticks')

sns.lmplot(x='popularity', y='acousticness', data=songs_df, scatter=False)

# %%
sns.lmplot(x='popularity', y='danceability', data=songs_df, scatter=False)

# %%
sns.lmplot(x='popularity', y='energy', data=songs_df, scatter=False)

# %%
sns.lmplot(x='popularity', y='valence', data=songs_df, scatter=False)
